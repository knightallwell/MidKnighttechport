# %% [markdown]
# Connected to Python 3.12.4

# %%
import folium.map

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import wget

# %%
import folium

# %%
from folium.features import DivIcon

# %%
from folium.plugins import MousePosition

# %%
from folium.plugins import MarkerCluster

# %%
space11=wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')

# %%
space11df=pd.read_csv(space11)

# %%
space1=space11df[['Launch Site', 'class', 'Lat', 'Long']]

# %%
space2=space1.groupby(['Launch Site'],as_index=False).first()

# %%
space1
# Out:
#      Launch Site  class        Lat        Long
# 0    CCAFS LC-40      0  28.562302  -80.577356
# 1    CCAFS LC-40      0  28.562302  -80.577356
# 2    CCAFS LC-40      0  28.562302  -80.577356
# 3    CCAFS LC-40      0  28.562302  -80.577356
# 4    CCAFS LC-40      0  28.562302  -80.577356
# 5    CCAFS LC-40      0  28.562302  -80.577356
# 6    CCAFS LC-40      0  28.562302  -80.577356
# 7    CCAFS LC-40      0  28.562302  -80.577356
# 8    CCAFS LC-40      0  28.562302  -80.577356
# 9    CCAFS LC-40      0  28.562302  -80.577356
# 10   CCAFS LC-40      0  28.562302  -80.577356
# 11   CCAFS LC-40      0  28.562302  -80.577356
# 12   CCAFS LC-40      0  28.562302  -80.577356
# 13   CCAFS LC-40      0  28.562302  -80.577356
# 14   CCAFS LC-40      0  28.562302  -80.577356
# 15   CCAFS LC-40      0  28.562302  -80.577356
# 16   CCAFS LC-40      0  28.562302  -80.577356
# 17   CCAFS LC-40      1  28.562302  -80.577356
# 18   CCAFS LC-40      1  28.562302  -80.577356
# 19   CCAFS LC-40      0  28.562302  -80.577356
# 20   CCAFS LC-40      1  28.562302  -80.577356
# 21   CCAFS LC-40      1  28.562302  -80.577356
# 22   CCAFS LC-40      1  28.562302  -80.577356
# 23   CCAFS LC-40      0  28.562302  -80.577356
# 24   CCAFS LC-40      1  28.562302  -80.577356
# 25   CCAFS LC-40      1  28.562302  -80.577356
# 26   VAFB SLC-4E      0  34.632834 -120.610745
# 27   VAFB SLC-4E      0  34.632834 -120.610745
# 28   VAFB SLC-4E      1  34.632834 -120.610745
# 29   VAFB SLC-4E      1  34.632834 -120.610745
# 30   VAFB SLC-4E      1  34.632834 -120.610745
# 31   VAFB SLC-4E      1  34.632834 -120.610745
# 32   VAFB SLC-4E      0  34.632834 -120.610745
# 33   VAFB SLC-4E      0  34.632834 -120.610745
# 34   VAFB SLC-4E      0  34.632834 -120.610745
# 35   VAFB SLC-4E      0  34.632834 -120.610745
# 36    KSC LC-39A      1  28.573255  -80.646895
# 37    KSC LC-39A      0  28.573255  -80.646895
# 38    KSC LC-39A      1  28.573255  -80.646895
# 39    KSC LC-39A      1  28.573255  -80.646895
# 40    KSC LC-39A      0  28.573255  -80.646895
# 41    KSC LC-39A      1  28.573255  -80.646895
# 42    KSC LC-39A      1  28.573255  -80.646895
# 43    KSC LC-39A      0  28.573255  -80.646895
# 44    KSC LC-39A      1  28.573255  -80.646895
# 45    KSC LC-39A      1  28.573255  -80.646895
# 46    KSC LC-39A      1  28.573255  -80.646895
# 47    KSC LC-39A      1  28.573255  -80.646895
# 48    KSC LC-39A      1  28.573255  -80.646895
# 49  CCAFS SLC-40      1  28.563197  -80.576820
# 50  CCAFS SLC-40      1  28.563197  -80.576820
# 51  CCAFS SLC-40      0  28.563197  -80.576820
# 52  CCAFS SLC-40      0  28.563197  -80.576820
# 53  CCAFS SLC-40      0  28.563197  -80.576820
# 54  CCAFS SLC-40      1  28.563197  -80.576820
# 55  CCAFS SLC-40      0  28.563197  -80.576820

# %%
space2
# Out:
#     Launch Site  class        Lat        Long
# 0   CCAFS LC-40      0  28.562302  -80.577356
# 1  CCAFS SLC-40      1  28.563197  -80.576820
# 2    KSC LC-39A      1  28.573255  -80.646895
# 3   VAFB SLC-4E      0  34.632834 -120.610745

# %%
space3=space2[['Launch Site', 'Lat', 'Long']]

# %%
# Start location is NASA Johnson Space Center

# %%
nasa_coordinate = [29.559684888503615, -95.0830971930759]

# %%
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name

# %%
circle =folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))

# %%
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )

# %%
site_map.add_child(circle)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_688f740b519ed54de3f038e90d69daf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_688f740b519ed54de3f038e90d69daf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_688f740b519ed54de3f038e90d69daf8 = L.map(
#                 &quot;map_688f740b519ed54de3f038e90d69daf8&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eccc66c6560b60cff5a8c1bce385eb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3eccc66c6560b60cff5a8c1bce385eb2.addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#             var circle_5e15550c2e3663b97a2ed7e1d609a6e2 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#         var popup_9089be05fa3109055399c20f539f3f07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53f959a1ff3a94926f5502bf5e479c07 = $(`&lt;div id=&quot;html_53f959a1ff3a94926f5502bf5e479c07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_9089be05fa3109055399c20f539f3f07.setContent(html_53f959a1ff3a94926f5502bf5e479c07);
#
#
#
#         circle_5e15550c2e3663b97a2ed7e1d609a6e2.bindPopup(popup_9089be05fa3109055399c20f539f3f07)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_688f740b519ed54de3f038e90d69daf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_688f740b519ed54de3f038e90d69daf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_688f740b519ed54de3f038e90d69daf8 = L.map(
#                 &quot;map_688f740b519ed54de3f038e90d69daf8&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eccc66c6560b60cff5a8c1bce385eb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3eccc66c6560b60cff5a8c1bce385eb2.addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#             var circle_5e15550c2e3663b97a2ed7e1d609a6e2 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#         var popup_9089be05fa3109055399c20f539f3f07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53f959a1ff3a94926f5502bf5e479c07 = $(`&lt;div id=&quot;html_53f959a1ff3a94926f5502bf5e479c07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_9089be05fa3109055399c20f539f3f07.setContent(html_53f959a1ff3a94926f5502bf5e479c07);
#
#
#
#         circle_5e15550c2e3663b97a2ed7e1d609a6e2.bindPopup(popup_9089be05fa3109055399c20f539f3f07)
#         ;
#
#
#
#
#             tile_layer_3eccc66c6560b60cff5a8c1bce385eb2.addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#             var marker_9b24224769544a7fcd66799fd9b29299 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_688f740b519ed54de3f038e90d69daf8);
#
#
#             var div_icon_5fee46dc57621fe2e69b3fa1eb299a8c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_9b24224769544a7fcd66799fd9b29299.setIcon(div_icon_5fee46dc57621fe2e69b3fa1eb299a8c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaabf786e6f2b9b90b6bb6fc05148f31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaabf786e6f2b9b90b6bb6fc05148f31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaabf786e6f2b9b90b6bb6fc05148f31 = L.map(
#                 &quot;map_aaabf786e6f2b9b90b6bb6fc05148f31&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_732fe8243d68b6e50f995872d9ac2ca0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_732fe8243d68b6e50f995872d9ac2ca0.addTo(map_aaabf786e6f2b9b90b6bb6fc05148f31);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Mc_cl=MarkerCluster()

# %%
def align_marker(Launch_outcome):
    if Launch_outcome ==1:
        return 'green'
    else:
        return 'yellow'

# %%
space1=space1['class'].apply(align_marker)

# %%
space1
# Out:
# 0     yellow
# 1     yellow
# 2     yellow
# 3     yellow
# 4     yellow
# 5     yellow
# 6     yellow
# 7     yellow
# 8     yellow
# 9     yellow
# 10    yellow
# 11    yellow
# 12    yellow
# 13    yellow
# 14    yellow
# 15    yellow
# 16    yellow
# 17     green
# 18     green
# 19    yellow
# 20     green
# 21     green
# 22     green
# 23    yellow
# 24     green
# 25     green
# 26    yellow
# 27    yellow
# 28     green
# 29     green
# 30     green
# 31     green
# 32    yellow
# 33    yellow
# 34    yellow
# 35    yellow
# 36     green
# 37    yellow
# 38     green
# 39     green
# 40    yellow
# 41     green
# 42     green
# 43    yellow
# 44     green
# 45     green
# 46     green
# 47     green
# 48     green
# 49     green
# 50     green
# 51    yellow
# 52    yellow
# 53    yellow
# 54     green
# 55    yellow
# Name: class, dtype: object

# %% [markdown]
# No kernel connected
